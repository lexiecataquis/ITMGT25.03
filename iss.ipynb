# %%
import requests
import time
import matplotlib.pyplot as plt

url = "https://api.wheretheiss.at/v1/satellites/25544"

data_points = 100

timestamps = []
latitudes = []
longitudes = []

for _ in range(data_points):
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        timestamp = int(time.time())  
        latitude = data["latitude"]
        longitude = data["longitude"]
        timestamps.append(timestamp)
        latitudes.append(latitude)
        longitudes.append(longitude)
    time.sleep(1) 

plt.figure(figsize=(10, 6))
plt.plot(longitudes, latitudes, marker='o', linestyle='-', color='b')
plt.title('Path of the International Space Station - A Visualization')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.grid(True)
plt.tight_layout()
plt.show()

print(f"ISS's present location as of: {timestamp}")
print(f"   Latitude: {latitude}")
print(f"   Longitude: {longitude}")
# Out:
# ISS's present location as of: 1720016669
#    Latitude: 42.946910147731
#    Longitude: -131.32859049455
